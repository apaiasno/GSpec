# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Setup imaging system

# %%
dim = 100
x, y = np.linspace(-1, 1, dim+1), np.linspace(-1, 1, dim+1)
x, y = np.meshgrid(x, y)
A = np.zeros((dim+1, dim+1))
A[(x**2 + y**2) < 1] = 1
alpha, beta, phi = np.zeros_like(A), np.zeros_like(A), np.zeros_like(A)


plt.figure(figsize=(8,8))
plt.imshow(A)
plt.show()

# %%
x**2 + y**2
# Out:
# array([20000, 19602, 19208, 18818, 18432, 18050, 17672, 17298, 16928,
#        16562, 16200, 15842, 15488, 15138, 14792, 14450, 14112, 13778,
#        13448, 13122, 12800, 12482, 12168, 11858, 11552, 11250, 10952,
#        10658, 10368, 10082,  9800,  9522,  9248,  8978,  8712,  8450,
#         8192,  7938,  7688,  7442,  7200,  6962,  6728,  6498,  6272,
#         6050,  5832,  5618,  5408,  5202,  5000,  4802,  4608,  4418,
#         4232,  4050,  3872,  3698,  3528,  3362,  3200,  3042,  2888,
#         2738,  2592,  2450,  2312,  2178,  2048,  1922,  1800,  1682,
#         1568,  1458,  1352,  1250,  1152,  1058,   968,   882,   800,
#          722,   648,   578,   512,   450,   392,   338,   288,   242,
#          200,   162,   128,    98,    72,    50,    32,    18,     8,
#            2,     0,     2,     8,    18,    32,    50,    72,    98,
#          128,   162,   200,   242,   288,   338,   392,   450,   512,
# ...
